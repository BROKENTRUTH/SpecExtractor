# %%
import re
import textwrap
import pandas as pd
from pathlib import Path

try:
    import pdfplumber
except ImportError:
    import sys, subprocess
    print("Installing pdfplumber … (run manually if this fails)")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "pdfplumber"])
    import pdfplumber

try:
    from fpdf import FPDF, FPDFException
except ImportError:
    import sys, subprocess
    print("Installing fpdf2 … (run manually if this fails)")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "fpdf2"])
    from fpdf import FPDF, FPDFException


def extract_pages(pdf_path: Path):
    with pdfplumber.open(str(pdf_path)) as pdf:
        return [
            (i + 1, page.extract_text())
            for i, page in enumerate(pdf.pages)
            if page.extract_text()
        ]


def parse_material_sections(pages):
    data = []
    current_material, buffer, last_pg = None, [], 0

    material_patterns = [
        re.compile(r'^(\d+(?:\.\d+)*)\s+[A-Z][A-Za-z0-9 ,/\-()]+$'),
        re.compile(r'^(?:Material:?)\s+[A-Z][A-Za-z0-9 ,/\-()]+$', re.I),
        re.compile(r'^(?:Specification for)\s+[A-Z][A-Za-z0-9 ,/\-()]+$', re.I),
        re.compile(r'^[A-Z0-9][A-Z0-9 \-/]{10,}$')
    ]

    print("\nDetected material section headers:")

    for pg_num, text in pages:
        for ln in text.split('\n'):
            ln = ln.strip()
            if not ln:
                continue
            header_match = next((ln for pat in material_patterns if pat.match(ln)), None)
            if header_match:
                if current_material and buffer:
                    data.append((current_material, buffer, last_pg))
                current_material, buffer, last_pg = header_match, [], pg_num
                print(f"  → {current_material}  (page {last_pg})")
            else:
                buffer.append((ln, pg_num))
    if current_material and buffer:
        data.append((current_material, buffer, last_pg))
    return data


def extract_fields(material, buffer, start_pg):
    tests, defs, misc = [], [], []
    code_regex = re.compile(r"\b(?:IS|ASTM|BS|EN|DIN)\s*[- ]?\d+(?:[:\-]\d+)?", re.I)
    page_ref = lambda t, p: f"{t} (Page {p})"

    for line, pg in buffer:
        target = page_ref(line, pg)
        if code_regex.search(line) or re.search(r"\b(test|strength|absorption|method|procedure|requirement|classification)\b", line, re.I):
            tests.append(target)
        elif re.search(r"\b(type|grade|class|definition|composition|description|material|specification)\b", line, re.I):
            defs.append(target)
        else:
            misc.append(target)

    return {
        "Material Name": material,
        "Test Name/Reference Code/Standard as per the given document (with reference page number)": tests or ["No Information Available"],
        "Specific Material Type/Material Definition": defs or ["No Information Available"],
        "Any other relevant information": misc or ["No Information Available"]
    }


def clean_text(txt):
    if isinstance(txt, list):
        txt = '\n'.join(txt)
    txt = re.sub(r"(\S{120})", r"\1 ", txt)
    return txt.encode("latin-1", "replace").decode("latin-1")


def export_to_pdf(df: pd.DataFrame, filename="extracted_report.pdf"):
    class PDF(FPDF):
        def header(self):
            # Add a border box
            self.set_line_width(0.5)
            self.rect(10, 10, 190, 20)  # x, y, width, height
            self.set_font("Arial", 'B', 14)
            self.set_y(15)
            self.cell(0, 10, "Extracted Material Specification Table", ln=True, align='C')
            self.ln(4)

        def footer(self):
            pass


    pdf = PDF()
    pdf.set_auto_page_break(True, margin=15)
    pdf.add_page()
    pdf.set_font("Arial", size=10)

    col_widths = [10, 35, 65, 40, 40]
    headers = list(df.columns)


    pdf.set_fill_color(0, 102, 204)
    pdf.set_font("Arial", 'B', 10)
    for i, header in enumerate(headers):
        pdf.multi_cell(col_widths[i], 10, clean_text(header), border=1, align='C', fill=True, ln=3, max_line_height=pdf.font_size)
    pdf.ln()

    pdf.set_font("Arial", '', 9)
    fill = False
    pdf.set_fill_color(255, 255, 153)
    for idx, row in df.iterrows():

        pdf.ln(2)
        pdf.set_draw_color(180, 180, 180)
        pdf.line(10, pdf.get_y(), 200, pdf.get_y())
        pdf.ln(1)
        pdf.set_font("Arial", 'B', 11)
        pdf.set_fill_color(224, 224, 224)
        pdf.cell(0, 8, clean_text(f"Material Section {idx + 1}: {row['Material Name']}"), ln=True, fill=True)
        pdf.set_font("Arial", '', 9)
        fill = not fill

        row_data = [
            str(idx + 1),
            row['Material Name'],
            '\n'.join(row['Test Name/Reference Code/Standard as per the given document (with reference page number)']),
            '\n'.join(row['Specific Material Type/Material Definition']),
            '\n'.join(row['Any other relevant information'])
        ]
        for i, item in enumerate(row_data):
            if i == 1:
                pdf.set_font("Arial", 'B', 9)
            else:
                pdf.set_font("Arial", '', 9)
            pdf.multi_cell(col_widths[i], 6, clean_text(item), border=1, align='L', ln=3, max_line_height=pdf.font_size, fill=fill)
        pdf.ln()

    try:
        pdf.output(filename)
        print(f"PDF saved to {filename}")
    except FPDFException as e:
        print(f"FPDF error: {e}. Try shorter lines or different font size.")


def main():
    pdf_path = Path(input("Enter path to technical specification PDF: ").strip())
    if not pdf_path.exists():
        print("File not found.")
        return

    pages = extract_pages(pdf_path)
    if not pages:
        print("No text extracted – scanned PDF? Try OCR first.")
        return

    sections = parse_material_sections(pages)
    if not sections:
        print("No headers found – fallback to fixed‑size blocks.")
        block_sz, counter = 30, 1
        for pg, txt in pages:
            lines = [ln.strip() for ln in txt.split('\n') if ln.strip()]
            for i in range(0, len(lines), block_sz):
                blk = lines[i:i+block_sz]
                label = f"Material Block {counter} (Page {pg})"
                sections.append((label, [(l, pg) for l in blk], pg))
                counter += 1

    rows = [extract_fields(m, buf, pg) for m, buf, pg in sections]
    df = pd.DataFrame(rows)
    df.insert(0, "Sl. No.", range(1, len(df)+1))

    csv_name = "extracted_table.csv"
    excel_name = "extracted_table.xlsx"
    df.to_csv(csv_name, index=False)
    df.to_excel(excel_name, index=False)
    print(f"Excel saved to {excel_name}")
    print(f"CSV saved to {csv_name}")

    export_to_pdf(df)


if __name__ == "__main__":
    main()
# Out:
# Enter path to technical specification PDF: /content/Prescriptive Specifications_CPWD.pdf
#
# Detected material section headers:
#   → 4.0 CONCRETE WORK  (page 1)
#   → 4.1.1 Coarse Aggregate  (page 1)
#   → 4.1.1.3 Size and Grading  (page 1)
#   → CPWD SPECIFICATIONS 2019  (page 1)
#   → 4.1.2 Chemical Admixtures  (page 3)
#   → CPWD SPECIFICATIONS 2019  (page 3)
#   → 4.1.2.5 Some admixture may be in the form of powder, particle or high concentration liquids which may  (page 4)
#   → 4.1.2.7 Certain admixtures may contain significant amounts of finely divided insoluble materials or  (page 4)
#   → 4.1.2.9 No admixtures shall be accepted for use in concrete unless these are tested in accordance with  (page 4)
#   → 4.2.1 Grades of Cement Concrete  (page 4)
#   → 4.2.1.1 The characteristic strength is defined as the strength of material below which not more than 5  (page 5)
#   → CPWD SPECIFICATIONS 2019 92  (page 5)
#   → 4.2.2 Workability of Concrete  (page 6)
#   → 4.2.2.1 The concrete mix proportion chosen should be such that the concrete is of adequate  (page 6)
#   → 4.2.3 Concrete Mix Proportioning  (page 6)
#   → 4.2.3.1 The determination of the proportion of cement, aggregate and water to attain the required  (page 6)
#   → 4.2.4 Batching  (page 7)
#   → CPWD SPECIFICATIONS 2019 94  (page 7)
#   → 4.2.4.1 In case of batch mixing plant at site the grading of aggregate shall be controlled by  (page 8)
#   → 4.2.4.3 All ingredients of concrete shall be used by mass except water and chemical admixtures  (page 8)
#   → 4.2.4.4 Volume batching may be allowed only where weigh-batching is not practicable and provided  (page 8)
#   → 4.2.4.6 No substitutions in materials used on the work or alteration in the established proportions,  (page 9)
#   → 4.2.5 Mixing  (page 9)
#   → CPWD SPECIFICATIONS 2019 96  (page 9)
#   → 4.2.6 Placing  (page 11)
#   → 4.2.7 Compaction  (page 11)
#   → 4.2.8 Construction Joints  (page 11)
#   → 4.2.8.1 When the work has to be resumed on a surface which has hardened, such surface shall be  (page 11)
#   → CPWD SPECIFICATIONS 2019 98  (page 11)
#   → 4.2.8.2 Where the concrete has not fully hardened, all laitance shall be removed by scrubbing the  (page 12)
#   → 4.2.9 Concreting under Special Conditions  (page 12)
#   → 4.2.10 Curing  (page 12)
#   → 4.2.10.4 Over the foundation concrete, the masonry work may be started after 48 hours of its  (page 13)
#   → 4.2.11 Testing of Concrete  (page 13)
#   → 4.2.12 Form Work  (page 13)
#   → 4.2.13 Finishes  (page 13)
#   → 4.2.14 Durability of Concrete  (page 13)
#   → CPWD SPECIFICATIONS 2019 100  (page 13)
#   → 4.2.14.1 Requirements for Durability  (page 14)
#   → CPWD SPECIFICATIONS 2019 102  (page 15)
#   → 4.2.15 Measurements  (page 17)
#   → 4.2.15.3 Cast-in -situ concrete and or precast concrete work shall be measured in stages described in the  (page 17)
#   → CPWD SPECIFICATIONS 2019 104  (page 17)
#   → 4.2.15.7 Precast cement concrete ssolid article shall be measured separately and shaall include use of  (page 18)
#   → 4.2.16 Rate  (page 19)
#   → 4.3 CEMENT- FLY ASH CONCRETE  (page 19)
#   → 4.3.0 Fly ash concrete shall be prepared by mixing graded coarse aggregate of nominal size as  (page 19)
#   → 4.3.1 Proportioning  (page 19)
#   → CPWD SPECIFICATIONS 2019 106  (page 19)
#   → 4.3.7 Rate  (page 20)
#   → 4.4 DAMP PROOF COURSE  (page 20)
#   → 4.4.1 Cement Concrete Layer  (page 20)
#   → 4.4.2 Curing  (page 20)
#   → 4.4.3 Application of Hot Bitumen  (page 20)
#   → 4.4.4 Water Proofing Materials  (page 20)
#   → 4.4.5 Measurements  (page 20)
#   → 4.4.6 Rate  (page 20)
#   → DETERMINATION OF PARTICLE SIZE  (page 21)
#   → TEST FOR SURFACE MOISTURE  (page 21)
#   → CPWD SPECIFICATIONS 2019 108  (page 21)
#   → DETERMINATION OF TEN PER CENT FINE VALUE  (page 22)
#   → CPWD SPECIFICATIONS 2019 110  (page 23)
#   → REINFORCED CEMENT  (page 26)
#   → CONCRETE WORK  (page 26)
#   → 5.0 General 128  (page 28)
#   → 5.1 Materials 128  (page 28)
#   → 5.1.1 Water, Cement, Fine and Coarse Aggregate 128  (page 28)
#   → 5.1.2 Fly Ash Admixed Cement Concrete (FACC) and Fly 128  (page 28)
#   → 5.1.3 Steel for Reinforcement 129  (page 28)
#   → 5.1.5 Identification 132  (page 28)
#   → 5.2.1 Form Work 132  (page 28)
#   → 5.2.3 General Requirement 132  (page 28)
#   → 5.2.4 Surface Treatment 134  (page 28)
#   → 5.2.5 Inspection of Form Work 135  (page 28)
#   → 5.2.5.1 Erection of Form Work (Centering and shuttering) 135  (page 28)
#   → 5.2.5.2 Guidelines for Multistage Centering 136  (page 28)
#   → 5.2.6 Measurements 136  (page 28)
#   → 5.2.7 Rate 138  (page 28)
#   → 5.3 Reinforcements 138  (page 28)
#   → 5.3.1 General Requirements 138  (page 28)
#   → 5.3.2 Welding of Bars 139  (page 28)
#   → 5.3.3 Placing in Position 139  (page 29)
#   → 5.3.4 Measurements 140  (page 29)
#   → 5.3.5 Rate 140  (page 29)
#   → 5.4 Concreting 145  (page 29)
#   → 5.4.1 Consistency 145  (page 29)
#   → 5.4.2 Placing of Concrete 145  (page 29)
#   → 5.4.3 Compaction 146  (page 29)
#   → 5.4.4 Construction Joints 147  (page 29)
#   → 5.4.5 Expansion Joints 147  (page 29)
#   → 5.4.6 Curing 147  (page 29)
#   → CPWD SPECIFICATIONS 2019 116  (page 29)
#   → 5.4.7 Rectification of Surface Defects of Minor nature 147  (page 30)
#   → 5.4.8 Strength of Concrete 148  (page 30)
#   → 5.4.9 Testing of Concrete 149  (page 30)
#   → 5.4.10 Standard of Acceptance for Nominal Mix 149  (page 30)
#   → 5.4.11 Measurements 152  (page 30)
#   → 5.4.12 Tolerances 154  (page 30)
#   → 5.4.13 Rate 154  (page 30)
#   → 5.5 Encasing Rolled Steel Sections 155  (page 30)
#   → 5.5.1 General Requirements 155  (page 30)
#   → 5.5.2 Wrapping 155  (page 30)
#   → 5.5.3 Form Work 156  (page 30)
#   → 5.5.4 Concreting 156  (page 30)
#   → 5.5.5 Measurements 156  (page 30)
#   → 5.5.6 Rate 156  (page 30)
#   → 5.6 Precast Reinforced Concrete 156  (page 30)
#   → 5.7 Precast Cement Concrete Jali 159  (page 31)
#   → 5.7.1 Fixing 159  (page 31)
#   → 5.7.2 Measurements 159  (page 31)
#   → 5.7.3 Rate 159  (page 31)
#   → 5.8 Design Mix 161  (page 31)
#   → 5.8.0 Definition 161  (page 31)
#   → CPWD SPECIFICATIONS 2019 118  (page 31)
#   → 5.8.1 Mix Design and Proportioning 161  (page 32)
#   → 5.8.2 Standard Deviation 161  (page 32)
#   → 5.8.3 Acceptance Criteria for Design Mix 161  (page 32)
#   → 5.8.4 Cement Content of Concrete 162  (page 32)
#   → 5.8.5 Water Cement Ratio and Slump 162  (page 32)
#   → 5.8.6 Approval of Design Mix 163  (page 32)
#   → 5.9 Ready Mixed Concrete (As per IS 4926) 175  (page 33)
#   → 5.9.1 Materials 175  (page 33)
#   → 5.9.2 General Requirements 176  (page 33)
#   → 5.9.3 Sampling and Testing of Ready - Mixed Concrete 177  (page 33)
#   → 5.9.4 Information to be Supplied by the Purchaser 178  (page 33)
#   → 5.9.5 Information to be Supplied by the Producer 178  (page 33)
#   → 5.9.6 Production and Delivery 179  (page 33)
#   → 5.9.7 Quality Control 181  (page 33)
#   → 5.9.8 Order Processing 183  (page 33)
#   → 5.9.9 Records 183  (page 33)
#   → 5.10 Placing Concrete by Pumping 183  (page 33)
#   → 5.10.1 General 183  (page 33)
#   → 5.10.2 Pumping Equipments 183  (page 33)
#   → 5.11 Guidelines for Field Practice 185  (page 33)
#   → 5.11.1 General Precautions 185  (page 33)
#   → 5.11.2 Submittals 187  (page 33)
#   → 5.11.3 Sampling and Testing (Materials) 187  (page 33)
#   → 5.11.4 Sampling and Testing for Quality Control of Fresh 190  (page 33)
#   → 5.11.5 Sampling and Testing for Quality Control of Hardened 192  (page 33)
#   → CPWD SPECIFICATIONS 2019 120  (page 33)
#   → 5.12 Expansion joint system 194  (page 34)
#   → 5.12.1 Floor joint 194  (page 34)
#   → 5.12.1.1 General requirement of material 194  (page 34)
#   → 5.12.1.2 Performance requirement 194  (page 34)
#   → 5.12.1.3 Approval of expansion joint system 194  (page 34)
#   → 5.12.1.4 Installation of expansion joint system 194  (page 34)
#   → 5.12.1.5 Measurement 194  (page 34)
#   → 5.12.1.6 Rate 194  (page 34)
#   → 5.12.2 Wall joint 194  (page 34)
#   → 5.12.2.1 General requirement of material 194  (page 34)
#   → 5.12.2.2 Performance requirement 195  (page 34)
#   → 5.12.2.3 Approval of expansion joint system 195  (page 34)
#   → 5.12.2.4 Installation of expansion joint system 195  (page 34)
#   → 5.12.2.5 Measurement 195  (page 34)
#   → 5.12.2.6 Rate 195  (page 34)
#   → 5.12.3 Roof joint 195  (page 34)
#   → 5.12.3.1 General requirement of material 195  (page 34)
#   → 5.12.3.2 Performance requirement 195  (page 34)
#   → 5.12.3.3 Approval of expansion joint system 195  (page 34)
#   → 5.12.3.4 Installation of expansion joint system 195  (page 34)
#   → 5.12.3.5 Measurement 195  (page 34)
#   → 5.12.3.6 Rate 195  (page 34)
#   → 5.25 Roof Level  (page 35)
#   → CPWD SPECIFICATIONS 2019 122  (page 35)
#   → LIST OF MANDATORY TESTS  (page 36)
#   → Material Clause Test Field/ Test Min, quantity of Frequency  (page 36)
#   → 1 2 3 4 5 6 7  (page 36)
#   → 1 2 3 4 5 6 7  (page 37)
#   → CPWD SPECIFICATIONS 2019 124  (page 37)
#   → 1 2 3 4 5 6 7  (page 38)
#   → LIST OF BUREAU OF INDIAN STANDARDS CODES  (page 40)
#   → 5.0 REINFORCED CEMENT CONCRETE WORK  (page 41)
#   → 5.0 GENERAL  (page 41)
#   → 5.1 MATERIALS  (page 41)
#   → 5.1.1 Water, cement, fine and coarse aggregate shall be as specified under respective clauses of  (page 41)
#   → 5.1.2 Fly Ash admixed cement concrete (FACC) and fly ash Blended cements in Cement Concrete  (page 41)
#   → 5.1.2.0 Fly ash Blended Cements conforming to IS 1489 (Part I) may be used in RCC structures as per  (page 41)
#   → 5.1.2.1 General  (page 41)
#   → CPWD SPECIFICATIONS 2019 128  (page 41)
#   → 5.1.3 Steel for Reinforcement  (page 42)
#   → 5.1.3.3 Mild steel is not recommenndded for the use in structures located in earthquakkee zone subjected to  (page 42)
#   → 5.1.3.4 Welding of reinforcement bbaars covered in this specification shall be done in aaccordance with the  (page 42)
#   → 415 415 D 500 D 550 D  (page 43)
#   → CPWD SPECIFICATIONS 2019 130  (page 43)
#   → 5.1.4 Stacking and Storage  (page 44)
#   → 5.1.5 Identification  (page 45)
#   → 5.2.1 Form Work  (page 45)
#   → 5.2.3 General Requirement  (page 45)
#   → 5.2.3.1 Material for Form Work  (page 45)
#   → CPWD SPECIFICATIONS 2019 132  (page 45)
#   → 5.2.3.4 Form work shall be properly designed for self weight, weight of reinforcement, weight of fresh  (page 46)
#   → 5.2.4 Surface Treatment  (page 47)
#   → CPWD SPECIFICATIONS 2019 134  (page 47)
#   → 5.2.5 Inspection of Form Work  (page 48)
#   → 5.2.6 MEASUREMENTS  (page 49)
#   → CPWD SPECIFICATIONS 2019 136  (page 49)
#   → 5.2.6.4 Where it is not specifically stated in the description of the item that form work shall be paid for  (page 50)
#   → 5.2.6.5 No deductions from the shuttering due to the openings/ obstructions shall be made if the  (page 50)
#   → 5.2.6.6 Form work of elements measured under categories of arches, arch ribs, domes, spiral  (page 51)
#   → 5.2.6.7 Extra for circular work shall be admissible for surfaces circular or curvilinear in plan or in  (page 51)
#   → 5.2.7 Rate  (page 51)
#   → 5.3 REINFORCEMENTS  (page 51)
#   → 5.3.1 General Requirements  (page 51)
#   → CPWD SPECIFICATIONS 2019 138  (page 51)
#   → 5.3.2 Welding of Bars  (page 52)
#   → 5.3.3.1 Fabricated reinforcement bars shall be placed in position as shown in the drawings or as directed by  (page 52)
#   → 5.3.4 Measurement  (page 53)
#   → 5.3.5 Rate  (page 53)
#   → CPWD SPECIFICATIONS 2019 140  (page 53)
#   → 500 D 550 D  (page 54)
#   → CPWD SPECIFICATIONS 2019 142  (page 55)
#   → CPWD SPECIFICATIONS 2019 144  (page 57)
#   → 5.4 CONCRETING  (page 58)
#   → 5.4.1 Consistency  (page 58)
#   → 5.4.2 Placing of Concrete  (page 58)
#   → 5.4.2.1 Concreting shall be commenced only after Engineer-in-Charge has inspected the centering,  (page 58)
#   → 5.4.2.2 In case of concreting of slab and beams, wooden plank or cat walks of chequerred MS plated  (page 58)
#   → 5.4.2.4 The concrete shall be deposited in its final position in a manner to preclude segregation of  (page 59)
#   → 5.4.2.6 During hot weather precaution shall be taken to see that the temperature of wet concrete  (page 59)
#   → 5.4.2.7 It is necessary that the time between mixing and placing of concrete shall not exceed 30  (page 59)
#   → 5.4.3 Compaction  (page 59)
#   → 5.4.3.1 Concrete shall be compacted into dense mass immediately after placing by means of  (page 59)
#   → 5.4.3.2 Concrete shall be judged to be properly compacted, when the mortar fills the spaces between  (page 59)
#   → 5.4.3.3 In case of roof slabs the top surface shall be finished even and smooth with wooden  (page 59)
#   → CPWD SPECIFICATIONS 2019 146  (page 59)
#   → 5.4.4 Construction joints  (page 60)
#   → 5.4.4.2 In case of columns the joints shall be horizontal and 10 to 15 cm below the bottom of the beam  (page 60)
#   → 5.4.4.3 When stopping the concrete on a vertical plane in slabs and beams, and approved stop board  (page 60)
#   → 5.4.4.4 When the work has to be resumed, the joint shall be thoroughly cleaned with wire brush and  (page 60)
#   → 5.4.5 Expansion Joints  (page 60)
#   → 5.4.6 Curing  (page 60)
#   → 5.4.7 Rectification of Surface defects of Minor nature  (page 60)
#   → CPWD SPECIFICATIONS 2019 148  (page 61)
#   → 5.4.9 Testing of Concrete  (page 62)
#   → 5.4.9.0 Regular mandatory tests on the workability of the fresh concrete shall be done to achieve  (page 62)
#   → 5.4.10.2 Out of six sample cubes, three cubes shall be tested at 7 days and remaining three cubes  (page 62)
#   → CPWD SPECIFICATIONS 2019 150  (page 63)
#   → 5.4.11 Measurements  (page 65)
#   → 5.4.11.1 Dimensions shall be measured nearest to a cm except for the thickness of slab which shall  (page 65)
#   → CPWD SPECIFICATIONS 2019 152  (page 65)
#   → 5.4.11.2 Reinforced cement concrete whether cast-in-situ or pre cast shall be classified and measured  (page 66)
#   → 5.4.12 Tolerances  (page 67)
#   → 5.4.13 Rate  (page 67)
#   → 5.4.13.1 The rate included the cost of materials and labour involved in all the operations described  (page 67)
#   → 5.4.13.2 On the basis of mandatory lab tests, in case of actual average compressive strength being  (page 67)
#   → CPWD SPECIFICATIONS 2019 154  (page 67)
#   → 5.4.13.3 Where throating or plaster drip or moulding is not required to be provided in RCC chajjas,  (page 68)
#   → 5.4.13.4 No extra payment for richer mix which projects into any member from another member  (page 68)
#   → 5.5 ENCASING ROLLED STEEL SECTIONS  (page 68)
#   → 5.5.1 General Requirements  (page 68)
#   → 5.5.2 Wrapping  (page 68)
#   → 5.5.2.2 In the case of beams and grillages, the wire mesh or expanded metal shall be wrapped round  (page 68)
#   → 5.5.4 Concreting  (page 69)
#   → 5.5.5 Measurements  (page 69)
#   → 5.5.6 Rate  (page 69)
#   → 5.6 PRECAST REINFORCED CONCRETE  (page 69)
#   → 5.6.1 General Requirements  (page 69)
#   → 5.6.2 Concrete used for precasting the units should be well proportioned, mixed, placed and  (page 69)
#   → 5.6.3 Precast articles shall have a dense surface finish showing no coarse aggregate and shall  (page 69)
#   → CPWD SPECIFICATIONS 2019 156  (page 69)
#   → 5.6.4 The longitudinal reinforcement shall have a minimum cover of 12 mm or twice the diameter of  (page 70)
#   → 5.6.5 Curing  (page 70)
#   → 5.6.6 The precast articles shall be matured for 28 days before erection or being built in so that the  (page 70)
#   → 5.6.7 Marking  (page 70)
#   → 5.6.8 Precast units shall be stored, transported and placed in position in such as manner that they  (page 70)
#   → CPWD SPECIFICATIONS 2019 158  (page 71)
#   → 5.7 PRECAST CEMENT CONCRETE JALI  (page 72)
#   → 5.7.1 Fixing  (page 72)
#   → 5.7.2 Measurements  (page 72)
#   → 5.7.3 Rate  (page 72)
#   → CPWD SPECIFICATIONS 2019 160  (page 73)
#   → 5.8 DESIGN MIX  (page 74)
#   → 5.8.0 Definition  (page 74)
#   → 5.8.1 Mix Design and Proportioning  (page 74)
#   → 5.8.1.1 Mix proportions shall be designed to ensure that the workability of fresh concrete is suitable  (page 74)
#   → 5.8.1.2 Determination of the proportions by weight of cement, aggregates and water shall be based  (page 74)
#   → 5.8.1.3 As a trial the manufacturer of concrete may prepare a preliminary mix according to provisions  (page 74)
#   → 5.8.1.4 Mix design shall be tried and the mix proportions checked on the basis of tests conducted at  (page 74)
#   → 5.8.1.5 All concrete proportions for various grades of concrete shall be designed separately and the  (page 74)
#   → 5.8.1.6 Before using an admixture in concrete, its performance shall be evaluated by comparing the  (page 74)
#   → 5.8.2 Standard Deviation  (page 74)
#   → 5.8.2.1 Standard deviation calculations of test results based on tests conducted on the same mix  (page 74)
#   → 5.8.3 Acceptance Criteria for Design Mix  (page 74)
#   → 5.8.3.6 Concrete is liable to be rejected if it is porous or honey-combed, its placing has been interrupted  (page 75)
#   → 5.8.4 Cement Content of Concrete  (page 75)
#   → 5.8.4.1 For all grades of concrete manufactured/produced, minimum cement content in the concrete  (page 75)
#   → 5.8.4.2 Actual cement content in each grade of concrete for various conditions of variable shall be  (page 75)
#   → 5.8.5 Water Cement Ratio and Slump  (page 75)
#   → 5.8.5.1 In proportioning a particular mix, the manufacturer/ producer/ contractor shall give due  (page 75)
#   → CPWD SPECIFICATIONS 2019 162  (page 75)
#   → 5.8.6 Approval of Design Mix  (page 76)
#   → 5.8.6.1 The producer/ manufacturer/ contractor of concrete shall submit details of each trial mix of  (page 76)
#   → 5.8.6.2 For any change in quality/ quantity in the ingredients of a particular concrete, for which mix  (page 76)
#   → AND SEISMIC ARRESTERS  (page 76)
#   → CPWD SPECIFICATIONS 2019 164  (page 77)
#   → CPWD SPECIFICATIONS 2019 166  (page 79)
#   → CPWD SPECIFICATIONS 2019 168  (page 81)
#   → CPWD SPECIFICATIONS 2019 170  (page 83)
#   → CPWD SPECIFICATIONS 2019 172  (page 85)
#   → CPWD SPECIFICATIONS 2019 174  (page 87)
#   → 5.9 READY MIXED CONCRETE (as per IS 4926)  (page 88)
#   → 5.9.1 Materials  (page 88)
#   → 5.9.2 General Requirements  (page 89)
#   → CPWD SPECIFICATIONS 2019  (page 89)
#   → 5.9.3.3 Specified Strength  (page 90)
#   → 5.9.4 Information to be Supplied by the Purchaser  (page 91)
#   → 5.9.4.1 The purchaser shall provide to the producer the details of the concrete mix or mixes  (page 91)
#   → 5.9.5 Information to be Supplied by the Producer  (page 91)
#   → CPWD SPECIFICATIONS 2019  (page 91)
#   → 5.9.6 Production and Delivery  (page 92)
#   → 5.9.6.1 Materials Storage and Handling  (page 92)
#   → CPWD SPECIFICATIONS 2019  (page 93)
#   → CPWD SPECIFICATIONS 2019  (page 95)
#   → 5.9.8 Order Processing  (page 96)
#   → 5.9.9 Records  (page 96)
#   → 5.10 PLACING CONCRETE BY PUMPING  (page 96)
#   → 5.10.1 General  (page 96)
#   → 5.10.2 Pumping Equipments  (page 96)
#   → CPWD SPECIFICATIONS 2019  (page 97)
#   → 5.11.1 General Precautions  (page 98)
#   → CPWD SPECIFICATIONS 2019  (page 99)
#   → 5.11.3 Sampling and Testing (Materials)  (page 100)
#   → Material or part thereof  (page 101)
#   → CPWD SPECIFICATIONS 2019  (page 101)
#   → 5.11.3.3 Water  (page 102)
#   → 5.11.3.4 Admixtures  (page 102)
#   → 5.11.4 Sampling and Testing for Quality Control of Fresh Concrete  (page 103)
#   → 5.11.4.1 Slump  (page 103)
#   → CPWD SPECIFICATIONS 2019 190  (page 103)
#   → 5.11.4.2 Compacting Factor  (page 104)
#   → 5.11.5 Sampling and Testing for Quality Control of Hardened Concrete  (page 105)
#   → CPWD SPECIFICATIONS 2019 192  (page 105)
#   → 5.12 EXPANSION JOINT SYSTEM  (page 107)
#   → 5.12.1 FLOOR JOINT  (page 107)
#   → 5.12.1.1 General requirement of material  (page 107)
#   → 5.12.2 WALL JOINT  (page 107)
#   → 5.12.2.1 General requirement of material  (page 107)
#   → material shall be such that it provides an Expansion joints systems suitable for vertical wall to wall/  (page 107)
#   → CPWD SPECIFICATIONS 2019 194  (page 107)
# Excel saved to extracted_table.xlsx
# CSV saved to extracted_table.csv
# /tmp/ipython-input-12-4060313443.py:111: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font("Arial", 'B', 14)
# /tmp/ipython-input-12-4060313443.py:113: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, "Extracted Material Specification Table", ln=True, align='C')
# /tmp/ipython-input-12-4060313443.py:123: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", size=10)
# /tmp/ipython-input-12-4060313443.py:130: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 10)
# /tmp/ipython-input-12-4060313443.py:132: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=3 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   pdf.multi_cell(col_widths[i], 10, clean_text(header), border=1, align='C', fill=True, ln=3, max_line_height=pdf.font_size)
# /tmp/ipython-input-12-4060313443.py:136: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:145: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 11)
# /tmp/ipython-input-12-4060313443.py:147: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 8, clean_text(f"Material Section {idx + 1}: {row['Material Name']}"), ln=True, fill=True)
# /tmp/ipython-input-12-4060313443.py:148: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:162: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:163: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=3 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   pdf.multi_cell(col_widths[i], 6, clean_text(item), border=1, align='L', ln=3, max_line_height=pdf.font_size, fill=fill)
# /tmp/ipython-input-12-4060313443.py:160: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 9)  # Bold for Material Name column
# /tmp/ipython-input-12-4060313443.py:111: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font("Arial", 'B', 14)
# /tmp/ipython-input-12-4060313443.py:113: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, "Extracted Material Specification Table", ln=True, align='C')
# /tmp/ipython-input-12-4060313443.py:145: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 11)
# /tmp/ipython-input-12-4060313443.py:147: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 8, clean_text(f"Material Section {idx + 1}: {row['Material Name']}"), ln=True, fill=True)
# /tmp/ipython-input-12-4060313443.py:148: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:162: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:163: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=3 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   pdf.multi_cell(col_widths[i], 6, clean_text(item), border=1, align='L', ln=3, max_line_height=pdf.font_size, fill=fill)
# /tmp/ipython-input-12-4060313443.py:160: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 9)  # Bold for Material Name column
# /tmp/ipython-input-12-4060313443.py:145: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 11)
# /tmp/ipython-input-12-4060313443.py:147: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 8, clean_text(f"Material Section {idx + 1}: {row['Material Name']}"), ln=True, fill=True)
# /tmp/ipython-input-12-4060313443.py:148: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:162: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:163: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=3 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   pdf.multi_cell(col_widths[i], 6, clean_text(item), border=1, align='L', ln=3, max_line_height=pdf.font_size, fill=fill)
# /tmp/ipython-input-12-4060313443.py:160: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 9)  # Bold for Material Name column
# /tmp/ipython-input-12-4060313443.py:111: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font("Arial", 'B', 14)
# /tmp/ipython-input-12-4060313443.py:113: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, "Extracted Material Specification Table", ln=True, align='C')
# /tmp/ipython-input-12-4060313443.py:111: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font("Arial", 'B', 14)
# /tmp/ipython-input-12-4060313443.py:113: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, "Extracted Material Specification Table", ln=True, align='C')
# /tmp/ipython-input-12-4060313443.py:145: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 11)
# /tmp/ipython-input-12-4060313443.py:147: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 8, clean_text(f"Material Section {idx + 1}: {row['Material Name']}"), ln=True, fill=True)
# /tmp/ipython-input-12-4060313443.py:148: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:162: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:163: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=3 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   pdf.multi_cell(col_widths[i], 6, clean_text(item), border=1, align='L', ln=3, max_line_height=pdf.font_size, fill=fill)
# /tmp/ipython-input-12-4060313443.py:160: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 9)  # Bold for Material Name column
# PDF saved to extracted_report.pdf
# /tmp/ipython-input-12-4060313443.py:162: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:163: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=3 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   pdf.multi_cell(col_widths[i], 6, clean_text(item), border=1, align='L', ln=3, max_line_height=pdf.font_size, fill=fill)
# /tmp/ipython-input-12-4060313443.py:145: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 11)
# /tmp/ipython-input-12-4060313443.py:147: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 8, clean_text(f"Material Section {idx + 1}: {row['Material Name']}"), ln=True, fill=True)
# /tmp/ipython-input-12-4060313443.py:148: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", '', 9)
# /tmp/ipython-input-12-4060313443.py:160: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", 'B', 9)  # Bold for Material Name column
# /tmp/ipython-input-12-4060313443.py:111: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   self.set_font("Arial", 'B', 14)
# /tmp/ipython-input-12-4060313443.py:113: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, "Extracted Material Specification Table", ln=True, align='C')
